# %% [markdown]
# # Calculate Price Elasticity of Demand

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

# %%
final_sell_calendar_households = pd.read_csv('final_sell_calendar_households.csv')

# %%
final_sell_calendar_hobbies = pd.read_csv('final_sell_calendar_hobbies.csv')

# %%
final_sell_calendar_foods = pd.read_csv('final_sell_calendar_foods.csv')

# %%
def calculate_ped(group):
    X = sm.add_constant(group['sell_price'])
    model = sm.OLS(group['amount'], X).fit()
    price_coef = model.params['sell_price']
    mean_sellprice = np.mean(group['sell_price'])
    mean_quantity = np.mean(group['amount'])
    ped = price_coef * (mean_sellprice / mean_quantity)
    return ped

# %% [markdown]
# ## Calculate PED for hobbies items

# %%
final_sell_calendar_hobbies =final_sell_calendar_hobbies.drop(final_sell_calendar_hobbies.columns[0], axis =1)

# %%
final_sell_calendar_hobbies
# Out:
#                          id  wm_yr_wk  sell_price      d  year  month  wday  \
# 0        HOBBIES_1_001_CA_1     11325        9.58  d_897  2013      7     1
# 1        HOBBIES_1_001_CA_1     11325        9.58  d_898  2013      7     2
# 2        HOBBIES_1_001_CA_1     11325        9.58  d_899  2013      7     3
# 3        HOBBIES_1_001_CA_1     11325        9.58  d_900  2013      7     4
# 4        HOBBIES_1_001_CA_1     11325        9.58  d_901  2013      7     5
# ...                     ...       ...         ...    ...   ...    ...   ...
# 8642680  HOBBIES_2_148_WI_3     11105        0.97   d_31  2011      2     3
# 8642681  HOBBIES_2_148_WI_3     11105        0.97   d_32  2011      3     4
# 8642682  HOBBIES_2_148_WI_3     11105        0.97   d_33  2011      3     5
# 8642683  HOBBIES_2_148_WI_3     11105        0.97   d_34  2011      3     6
# 8642684  HOBBIES_2_148_WI_3     11105        0.97   d_35  2011      3     7
#
#                date  amount  number
# 0        2013-07-13       0     897
# 1        2013-07-14       0     898
# 2        2013-07-15       0     899
# 3        2013-07-16       0     900
# 4        2013-07-17       0     901
# ...             ...     ...     ...
# 8642680  2011-02-28       0      31
# 8642681  2011-03-01       0      32
# 8642682  2011-03-02       0      33
# 8642683  2011-03-03       0      34
# 8642684  2011-03-04       0      35
#
# [8642685 rows x 10 columns]

# %%
final_sell_calendar_hobbies[['cat_id','dept_id','item_id', 'state_id','store_id']] = final_sell_calendar_hobbies['id'].str.split('_', expand=True)

# %%
ped_id = final_sell_calendar_hobbies.groupby('id').apply(calculate_ped)
print(ped_id)
# Out:
# /Users/chloeang/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# PED by id
# id
# HOBBIES_1_001_CA_1    -5.097742
# HOBBIES_1_001_CA_2    35.232799
# HOBBIES_1_001_CA_3    34.909486
# HOBBIES_1_001_CA_4    -4.440415
# HOBBIES_1_001_TX_1     0.833142
#                         ...
# HOBBIES_2_149_TX_2    -1.109734
# HOBBIES_2_149_TX_3    -0.940017
# HOBBIES_2_149_WI_1    -1.222426
# HOBBIES_2_149_WI_2    -0.790498
# HOBBIES_2_149_WI_3    -1.312173
# Length: 5650, dtype: float64

# %%
ped_item_id = final_sell_calendar_hobbies.groupby('item_id').apply(calculate_ped)
ped_item_id = ped_item_id.to_frame()
ped_item_id = ped_item_id.reset_index()
# Out:
# PED by item id
# item_id
# 001    3.978094
# 002    0.376649
# 003   -1.100386
# 004    2.916829
# 005   -3.049954
#          ...
# 420    0.012902
# 421   -2.901577
# 422   -2.203539
# 423   -0.878666
# 424    1.420512
# Length: 420, dtype: float64

# %%
ped_item_dept_id = final_sell_calendar_hobbies.groupby(['item_id','dept_id']).apply(calculate_ped)
ped_item_dept_id = ped_item_dept_id.to_frame()
ped_item_dept_id =ped_item_dept_id.reset_index()
# Out:
# PED by item id and dept id
# item_id  dept_id
# 001      1         -6.313660
#          2         -0.151866
# 002      1          1.685968
#          2          0.218097
# 003      1         -0.221408
#                       ...
# 420      1          0.012902
# 421      1         -2.901577
# 422      1         -2.203539
# 423      1         -0.878666
# 424      1          1.420512
# Length: 565, dtype: float64

# %%
ped_item_dept_state_id = final_sell_calendar_hobbies.groupby(['item_id','dept_id','state_id']).apply(calculate_ped)
ped_item_dept_state_id = ped_item_dept_state_id.to_frame()
ped_item_dept_state_id = ped_item_dept_state_id.reset_index()
# Out:
# /Users/chloeang/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
ped_item_dept_state_store_id = final_sell_calendar_hobbies.groupby(['item_id','dept_id','state_id','store_id']).apply(calculate_ped)
ped_item_dept_state_store_id = ped_item_dept_state_store_id.to_frame()
ped_item_dept_state_store_id = ped_item_dept_state_store_id.reset_index()
# Out:
# /Users/chloeang/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
a = ped_item_id.merge(ped_item_dept_id,left_on = 'item_id', right_on='item_id')
a
# Out:
#     item_id       0_x dept_id       0_y
# 0       001  3.978094       1 -6.313660
# 1       001  3.978094       2 -0.151866
# 2       002  0.376649       1  1.685968
# 3       002  0.376649       2  0.218097
# 4       003 -1.100386       1 -0.221408
# ..      ...       ...     ...       ...
# 560     420  0.012902       1  0.012902
# 561     421 -2.901577       1 -2.901577
# 562     422 -2.203539       1 -2.203539
# 563     423 -0.878666       1 -0.878666
# 564     424  1.420512       1  1.420512
#
# [565 rows x 4 columns]

# %%
b = a.merge(ped_item_dept_state_id,left_on =['item_id','dept_id'],right_on =['item_id','dept_id'])
# Out:
#      item_id       0_x dept_id       0_y state_id          0
# 0        001  3.978094       1 -6.313660       CA  -4.384036
# 1        001  3.978094       1 -6.313660       TX   0.174109
# 2        001  3.978094       1 -6.313660       WI -10.304710
# 3        001  3.978094       2 -0.151866       CA  -1.848419
# 4        001  3.978094       2 -0.151866       TX   0.259439
# ...      ...       ...     ...       ...      ...        ...
# 1690     423 -0.878666       1 -0.878666       TX   2.607444
# 1691     423 -0.878666       1 -0.878666       WI  -2.425794
# 1692     424  1.420512       1  1.420512       CA  -2.579196
# 1693     424  1.420512       1  1.420512       TX  -2.743452
# 1694     424  1.420512       1  1.420512       WI  -3.536496
#
# [1695 rows x 6 columns]

# %%
c = b.merge(ped_item_dept_state_store_id,left_on =['item_id','dept_id','state_id'],right_on =['item_id','dept_id','state_id'])
c
# Out:
# /Users/chloeang/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:9190: FutureWarning: Passing 'suffixes' which cause duplicate columns {'0_x'} in the result is deprecated and will raise a MergeError in a future version.
#   return merge(
#      item_id       0_x dept_id       0_y state_id       0_x store_id  \
# 0        001  3.978094       1 -6.313660       CA -4.384036        1
# 1        001  3.978094       1 -6.313660       CA -4.384036        2
# 2        001  3.978094       1 -6.313660       CA -4.384036        3
# 3        001  3.978094       1 -6.313660       CA -4.384036        4
# 4        001  3.978094       1 -6.313660       TX  0.174109        1
# ...      ...       ...     ...       ...      ...       ...      ...
# 5645     424  1.420512       1  1.420512       TX -2.743452        2
# 5646     424  1.420512       1  1.420512       TX -2.743452        3
# 5647     424  1.420512       1  1.420512       WI -3.536496        1
# 5648     424  1.420512       1  1.420512       WI -3.536496        2
# 5649     424  1.420512       1  1.420512       WI -3.536496        3
#
#             0_y
# 0     -5.097742
# 1     35.232799
# 2     34.909486
# 3     -4.440415
# 4      0.833142
# ...         ...
# 5645  -1.997759
# 5646  -0.580792
# 5647  -3.177566
# 5648  -2.644528
# 5649 -12.129071
#
# [5650 rows x 8 columns]

# %%
hobbies_ped = c.rename(columns={"0_x": "a", "0_y": "b", "0_y": "c"})

# %%
hobbies_ped.to_csv('hobbies_ped.csv')

# %% [markdown]
# ## Calculate PED for foods items

# %%
final_sell_calendar_foods = final_sell_calendar_foods.drop(final_sell_calendar_foods.columns[0],axis=1)

# %%
final_sell_calendar_foods[['cat_id','dept_id','item_id', 'state_id','store_id']] = final_sell_calendar_foods['id'].str.split('_', expand=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/7h/s4cspbv95x98l3h5nvklx3ym0000gn/T/ipykernel_5795/3087078412.py in <module>
# ----> 1 final_sell_calendar_foods[['cat_id','dept_id','item_id', 'state_id','store_id']] = final_sell_calendar_foods['id'].str.split('_', expand=True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3598             self._setitem_frame(key, value)
#    3599         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
#    3602             self._set_item_frame_value(key, value)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3639                 check_key_length(self.columns, key, value)
#    3640                 for k1, k2 in zip(key, value.columns):
# -> 3641                     self[k1] = value[k2]
#    3642
#    3643             elif not is_list_like(value):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4504         # We should never get here with DataFrame value
#    4505         if isinstance(value, Series):
# -> 4506             return _reindex_for_setitem(value, self.index)
#    4507
#    4508         if is_list_like(value):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in _reindex_for_setitem(value, index)
#   10769
#   10770     if value.index.equals(index) or not len(index):
# > 10771         return value._values.copy()
#   10772
#   10773     # GH#4107
#
# KeyboardInterrupt:

# %%
ped_id = final_sell_calendar_foods.groupby('id').apply(calculate_ped)
print(ped_id)

# %%
ped_item_id = final_sell_calendar_foods.groupby('item_id').apply(calculate_ped)
ped_item_id = ped_item_id.to_frame()
ped_item_id = ped_item_id.reset_index()

# %%
ped_item_dept_id = final_sell_calendar_foods.groupby(['item_id','dept_id']).apply(calculate_ped)
ped_item_dept_id = ped_item_dept_id.to_frame()
ped_item_dept_id =ped_item_dept_id.reset_index()

# %%
ped_item_dept_state_id = final_sell_calendar_foods.groupby(['item_id','dept_id','state_id']).apply(calculate_ped)
ped_item_dept_state_id = ped_item_dept_state_id.to_frame()
ped_item_dept_state_id = ped_item_dept_state_id.reset_index()

# %%
ped_item_dept_state_store_id = final_sell_calendar_foods.groupby(['item_id','dept_id','state_id','store_id']).apply(calculate_ped)
ped_item_dept_state_store_id = ped_item_dept_state_store_id.to_frame()
ped_item_dept_state_store_id = ped_item_dept_state_store_id.reset_index()

# %%
a = ped_item_id.merge(ped_item_dept_id,left_on = 'item_id', right_on='item_id')
a

# %%
final_sell_calendar_foods
# Out:
#                         id  wm_yr_wk  sell_price      d  year  month  wday  \
# 0         FOODS_1_001_CA_1     11325        2.24  d_897  2013      7     1
# 1         FOODS_1_001_CA_1     11325        2.24  d_898  2013      7     2
# 2         FOODS_1_001_CA_1     11325        2.24  d_899  2013      7     3
# 3         FOODS_1_001_CA_1     11325        2.24  d_900  2013      7     4
# 4         FOODS_1_001_CA_1     11325        2.24  d_901  2013      7     5
# ...                    ...       ...         ...    ...   ...    ...   ...
# 21395948  FOODS_3_825_WI_3     11105        4.00   d_31  2011      2     3
# 21395949  FOODS_3_825_WI_3     11105        4.00   d_32  2011      3     4
# 21395950  FOODS_3_825_WI_3     11105        4.00   d_33  2011      3     5
# 21395951  FOODS_3_825_WI_3     11105        4.00   d_34  2011      3     6
# 21395952  FOODS_3_825_WI_3     11105        4.00   d_35  2011      3     7
#
#                 date  amount  number cat_id dept_id
# 0         2013-07-13       2     897  FOODS       1
# 1         2013-07-14       0     898  FOODS       1
# 2         2013-07-15       1     899  FOODS       1
# 3         2013-07-16       3     900  FOODS       1
# 4         2013-07-17       0     901  FOODS       1
# ...              ...     ...     ...    ...     ...
# 21395948  2011-02-28       1      31  FOODS       3
# 21395949  2011-03-01       2      32  FOODS       3
# 21395950  2011-03-02       2      33  FOODS       3
# 21395951  2011-03-03       2      34  FOODS       3
# 21395952  2011-03-04       1      35  FOODS       3
#
# [21395953 rows x 12 columns]

# %% [markdown]
# ## Caculate PED for households items

# %%
final_sell_calendar_households =final_sell_calendar_households.drop(final_sell_calendar_households.columns[0],axis=1)

# %%
final_sell_calendar_households[['cat_id','dept_id','item_id', 'state_id','store_id']] = final_sell_calendar_households['id'].str.split('_', expand=True)

# %%
final_sell_calendar_households.to_csv('final_sell_calendar_households_2.csv')

# %%
final_sell_calendar_households
# Out:
#                             id  wm_yr_wk  sell_price      d  year  month  \
# 0         HOUSEHOLD_1_001_CA_1     11325        5.97  d_897  2013      7
# 1         HOUSEHOLD_1_001_CA_1     11325        5.97  d_898  2013      7
# 2         HOUSEHOLD_1_001_CA_1     11325        5.97  d_899  2013      7
# 3         HOUSEHOLD_1_001_CA_1     11325        5.97  d_900  2013      7
# 4         HOUSEHOLD_1_001_CA_1     11325        5.97  d_901  2013      7
# ...                        ...       ...         ...    ...   ...    ...
# 15989314  HOUSEHOLD_2_516_WI_3     11105        5.94   d_31  2011      2
# 15989315  HOUSEHOLD_2_516_WI_3     11105        5.94   d_32  2011      3
# 15989316  HOUSEHOLD_2_516_WI_3     11105        5.94   d_33  2011      3
# 15989317  HOUSEHOLD_2_516_WI_3     11105        5.94   d_34  2011      3
# 15989318  HOUSEHOLD_2_516_WI_3     11105        5.94   d_35  2011      3
#
#           wday        date  amount  number     cat_id dept_id item_id  \
# 0            1  2013-07-13       0     897  HOUSEHOLD       1     001
# 1            2  2013-07-14       0     898  HOUSEHOLD       1     001
# 2            3  2013-07-15       0     899  HOUSEHOLD       1     001
# 3            4  2013-07-16       0     900  HOUSEHOLD       1     001
# 4            5  2013-07-17       0     901  HOUSEHOLD       1     001
# ...        ...         ...     ...     ...        ...     ...     ...
# 15989314     3  2011-02-28       0      31  HOUSEHOLD       2     516
# 15989315     4  2011-03-01       0      32  HOUSEHOLD       2     516
# 15989316     5  2011-03-02       0      33  HOUSEHOLD       2     516
# 15989317     6  2011-03-03       0      34  HOUSEHOLD       2     516
# 15989318     7  2011-03-04       0      35  HOUSEHOLD       2     516
#
#          state_id store_id
# 0              CA        1
# 1              CA        1
# 2              CA        1
# 3              CA        1
# 4              CA        1
# ...           ...      ...
# 15989314       WI        3
# 15989315       WI        3
# 15989316       WI        3
# 15989317       WI        3
# 15989318       WI        3
#
# [15989319 rows x 15 columns]

# %%
ped_id_hh = final_sell_calendar_households.groupby('id').apply(calculate_ped)
ped_id_hh = ped_id_hh.to_frame()
ped_id_hh = ped_id_hh.reset_index()
