# %%
import pandas as pd

# %%
sales_train_evaluation = pd.read_csv('sales_train_evaluation.csv')

# %%
sales_train_validation = pd.read_csv('sales_train_validation.csv')

# %%
sales_train_validation
# Out:
#                                   id        item_id    dept_id   cat_id  \
# 0      HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1      HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2      HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3      HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4      HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                              ...            ...        ...      ...
# 30485    FOODS_3_823_WI_3_validation    FOODS_3_823    FOODS_3    FOODS
# 30486    FOODS_3_824_WI_3_validation    FOODS_3_824    FOODS_3    FOODS
# 30487    FOODS_3_825_WI_3_validation    FOODS_3_825    FOODS_3    FOODS
# 30488    FOODS_3_826_WI_3_validation    FOODS_3_826    FOODS_3    FOODS
# 30489    FOODS_3_827_WI_3_validation    FOODS_3_827    FOODS_3    FOODS
#
#       store_id state_id  d_1  d_2  d_3  d_4  ...  d_1904  d_1905  d_1906  \
# ...

# %%
sales_train_evaluation['cat_id'].unique()
# Out:
# array(['HOBBIES', 'HOUSEHOLD', 'FOODS'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
sales_train_evaluation
# Out:
#                                   id        item_id    dept_id   cat_id  \
# 0      HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_001  HOBBIES_1  HOBBIES
# 1      HOBBIES_1_002_CA_1_evaluation  HOBBIES_1_002  HOBBIES_1  HOBBIES
# 2      HOBBIES_1_003_CA_1_evaluation  HOBBIES_1_003  HOBBIES_1  HOBBIES
# 3      HOBBIES_1_004_CA_1_evaluation  HOBBIES_1_004  HOBBIES_1  HOBBIES
# 4      HOBBIES_1_005_CA_1_evaluation  HOBBIES_1_005  HOBBIES_1  HOBBIES
# ...                              ...            ...        ...      ...
# 30485    FOODS_3_823_WI_3_evaluation    FOODS_3_823    FOODS_3    FOODS
# 30486    FOODS_3_824_WI_3_evaluation    FOODS_3_824    FOODS_3    FOODS
# 30487    FOODS_3_825_WI_3_evaluation    FOODS_3_825    FOODS_3    FOODS
# 30488    FOODS_3_826_WI_3_evaluation    FOODS_3_826    FOODS_3    FOODS
# 30489    FOODS_3_827_WI_3_evaluation    FOODS_3_827    FOODS_3    FOODS
#
#       store_id state_id  d_1  d_2  d_3  d_4  ...  d_1932  d_1933  d_1934  \
# ...

# %%
sales_train_evaluation.groupby('state_id').count()['id'].sort_values().plot(kind='bar', figsize=(5, 2), title='Count of Items by state')
plt.show()

# %%
sales_train_evaluation.groupby('cat_id').count()['id'].sort_values().plot(kind='bar', figsize=(5, 2), title='Count of Items by Category')
plt.xticks(rotation=0)
plt.show()

# %%
selling_price = pd.read_csv('sell_prices.csv')

# %%
selling_price
# Out:
#         store_id        item_id  wm_yr_wk  sell_price
# 0           CA_1  HOBBIES_1_001     11325        9.58
# 1           CA_1  HOBBIES_1_001     11326        9.58
# 2           CA_1  HOBBIES_1_001     11327        8.26
# 3           CA_1  HOBBIES_1_001     11328        8.26
# 4           CA_1  HOBBIES_1_001     11329        8.26
# ...          ...            ...       ...         ...
# 6841116     WI_3    FOODS_3_827     11617        1.00
# 6841117     WI_3    FOODS_3_827     11618        1.00
# 6841118     WI_3    FOODS_3_827     11619        1.00
# 6841119     WI_3    FOODS_3_827     11620        1.00
# 6841120     WI_3    FOODS_3_827     11621        1.00
#
# [6841121 rows x 4 columns]

# %%
cats = selling_price['store_id'].unique()

# %%
cats
# Out:
# array(['CA_1', 'CA_2', 'CA_3', 'CA_4', 'TX_1', 'TX_2', 'TX_3', 'WI_1',
#        'WI_2', 'WI_3'], dtype=object)

# %%
import numpy as np

# %%
selling_price['sell_price'] = selling_price['sell_price'].apply(np.log1p)
category_data = selling_price[selling_price['item_id'].str.startswith('HOBBIES')]

# %%
category_data['sell_price'].describe()
# Out:
# count    1.283905e+06
# mean     1.585217e+00
# std      7.288707e-01
# min      9.950331e-03
# 25%      1.088562e+00
# 50%      1.603420e+00
# 75%      2.136531e+00
# max      3.465111e+00
# Name: sell_price, dtype: float64

# %%
# Create a histogram, bar chart, or any other suitable plot for each category
plt.figure(figsize=(8, 4))
plt.hist(category_data['sell_price'], bins=15,color = 'lightblue',ec = 'red')  # Example: Creating a histogram
plt.title(f'Distribution for Hobbies')
plt.xlabel('sell_price')
plt.ylabel('Freq')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
selling_price['sell_price'] = selling_price['sell_price'].apply(np.log1p)
category_data = selling_price[selling_price['item_id'].str.startswith('HOUSEHOLD')]

# %%
category_data['sell_price'].describe()
# Out:
# count    2.375427e+06
# mean     9.930545e-01
# std      1.883957e-01
# min      9.901152e-03
# 25%      8.676389e-01
# 50%      1.023066e+00
# 75%      1.123527e+00
# max      1.737847e+00
# Name: sell_price, dtype: float64

# %%
category_data['sell_price'].describe()
# Out:
# count    2.375427e+06
# mean     9.930545e-01
# std      1.883957e-01
# min      9.901152e-03
# 25%      8.676389e-01
# 50%      1.023066e+00
# 75%      1.123527e+00
# max      1.737847e+00
# Name: sell_price, dtype: float64

# %%
# Create a histogram, bar chart, or any other suitable plot for each category
plt.figure(figsize=(8, 4))
plt.hist(category_data['sell_price'], bins=10,color = 'lightblue',ec = 'red')  # Example: Creating a histogram
plt.title(f'Distribution for Households')
plt.xlabel('sell_price')
plt.ylabel('Freq')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
category_data = selling_price[selling_price['item_id'].str.startswith('FOOD')]

# %%
# Create a histogram, bar chart, or any other suitable plot for each category
plt.figure(figsize=(8, 4))
plt.hist(category_data['sell_price'], bins=10,color = 'lightblue',ec = 'red')  # Example: Creating a histogram
plt.title(f'Distribution for Food')
plt.xlabel('sell_price')
plt.ylabel('Freq')
plt.ticklabel_format(style='plain', axis='y')
plt.show()

# %%
category_data['sell_price'].describe()
# Out:
# count    3.181789e+06
# mean     8.375641e-01
# std      1.834600e-01
# min      9.901152e-03
# 25%      7.380839e-01
# 50%      8.341747e-01
# 75%      9.575977e-01
# max      1.391145e+00
# Name: sell_price, dtype: float64

# %%
mean = np.mean(selling_price[selling_price['item_id'].str.startswith('HOUSEHOLD')]['sell_price'])
mean
# Out:
# 0.9930545242572413

# %%
median = np.median(selling_price[selling_price['item_id'].str.startswith('HOUSEHOLD')]['sell_price'])
median
# Out:
# 1.0230655349706959

# %%
import statistics

# %%
mode = statistics.mode(selling_price[selling_price['item_id'].str.startswith('HOUSEHOLD')]['sell_price'])
mode
# Out:
# 0.9568259038664396

# %%
calendar = pd.read_csv('calendar.csv')
calendar
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 0     2011-01-29     11101   Saturday     1      1  2011     d_1
# 1     2011-01-30     11101     Sunday     2      1  2011     d_2
# 2     2011-01-31     11101     Monday     3      1  2011     d_3
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5
# ...          ...       ...        ...   ...    ...   ...     ...
# 1964  2016-06-15     11620  Wednesday     5      6  2016  d_1965
# 1965  2016-06-16     11620   Thursday     6      6  2016  d_1966
# 1966  2016-06-17     11620     Friday     7      6  2016  d_1967
# 1967  2016-06-18     11621   Saturday     1      6  2016  d_1968
# 1968  2016-06-19     11621     Sunday     2      6  2016  d_1969
#
#       event_name_1 event_type_1  event_name_2 event_type_2  snap_CA  snap_TX  \
# 0              NaN          NaN           NaN          NaN        0        0
# ...

# %%
merge = pd.merge(selling_price,calendar, on='wm_yr_wk')

# %%
merge
# Out:
#          store_id        item_id  wm_yr_wk  sell_price        date    weekday  \
# 0            CA_1  HOBBIES_1_001     11325    1.211633  2013-07-13   Saturday
# 1            CA_1  HOBBIES_1_001     11325    1.211633  2013-07-14     Sunday
# 2            CA_1  HOBBIES_1_001     11325    1.211633  2013-07-15     Monday
# 3            CA_1  HOBBIES_1_001     11325    1.211633  2013-07-16    Tuesday
# 4            CA_1  HOBBIES_1_001     11325    1.211633  2013-07-17  Wednesday
# ...           ...            ...       ...         ...         ...        ...
# 47735392     WI_3    FOODS_3_825     11105    0.959135  2011-02-28     Monday
# 47735393     WI_3    FOODS_3_825     11105    0.959135  2011-03-01    Tuesday
# 47735394     WI_3    FOODS_3_825     11105    0.959135  2011-03-02  Wednesday
# 47735395     WI_3    FOODS_3_825     11105    0.959135  2011-03-03   Thursday
# 47735396     WI_3    FOODS_3_825     11105    0.959135  2011-03-04     Friday
#
# ...

# %%
lg1= merge['item_id'].

# %%
df = selling_price[selling_price['item_id'].str.startswith('FOOD')]

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
df['sell_price'].describe().astype(float)
# Out:
# count   3181789.00
# mean          0.84
# std           0.18
# min           0.01
# 25%           0.74
# 50%           0.83
# 75%           0.96
# max           1.39
# Name: sell_price, dtype: float64

# %%
d_cols = [c for c in sales_train_evaluation.columns if 'd_' in c] # sales data columns

# %%
d_cols
# Out:
# ['d_1',
#  'd_2',
#  'd_3',
#  'd_4',
#  'd_5',
#  'd_6',
#  'd_7',
#  'd_8',
#  'd_9',
#  'd_10',
#  'd_11',
#  'd_12',
#  'd_13',
#  'd_14',
#  'd_15',
#  'd_16',
#  'd_17',
#  'd_18',
#  'd_19',
#  'd_20',
#  'd_21',
#  'd_22',
#  'd_23',
#  'd_24',
#  'd_25',
#  'd_26',
#  'd_27',
#  'd_28',
#  'd_29',
#  'd_30',
#  'd_31',
#  'd_32',
#  'd_33',
#  'd_34',
#  'd_35',
#  'd_36',
#  'd_37',
#  'd_38',
#  'd_39',
#  'd_40',
#  'd_41',
#  'd_42',
#  'd_43',
#  'd_44',
#  'd_45',
#  'd_46',
#  'd_47',
#  'd_48',
#  'd_49',
#  'd_50',
#  'd_51',
#  'd_52',
#  'd_53',
#  'd_54',
#  'd_55',
#  'd_56',
#  'd_57',
#  'd_58',
#  'd_59',
#  'd_60',
#  'd_61',
#  'd_62',
#  'd_63',
#  'd_64',
#  'd_65',
#  'd_66',
#  'd_67',
#  'd_68',
#  'd_69',
#  'd_70',
#  'd_71',
#  'd_72',
#  'd_73',
#  'd_74',
#  'd_75',
#  'd_76',
#  'd_77',
#  'd_78',
#  'd_79',
#  'd_80',
#  'd_81',
#  'd_82',
#  'd_83',
#  'd_84',
#  'd_85',
#  'd_86',
#  'd_87',
#  'd_88',
#  'd_89',
#  'd_90',
#  'd_91',
# ...

# %%
sales_train_evaluation.loc[sales_train_evaluation['id'] == 'HOBBIES_1_001_CA_1_evaluation'].set_index('id')[d_cols].T.plot(figsize=(15, 5),
          title='FOODS_3_090_CA_3 sales by "d" number')
# Out:
# <Axes: title={'center': 'FOODS_3_090_CA_3 sales by "d" number'}>

# %%
try1 = sales_train_evaluation.loc[sales_train_evaluation['cat_id'] == 'HOBBIES'].set_index('cat_id')[d_cols]

# %%
try1.sum(axis=0).T.plot(figsize=(15, 5),title='Hobbies sales by week')
# Out:
# <Axes: title={'center': 'Hobbies sales by week'}>

# %%
try2 = sales_train_evaluation.loc[sales_train_evaluation['cat_id'] == 'FOODS'].set_index('cat_id')[d_cols]

# %%
try2.sum(axis=0).T.plot(figsize=(15, 5),title='FOODS sales by week')
# Out:
# <Axes: title={'center': 'FOODS sales by week'}>

# %%
try3 = sales_train_evaluation.loc[sales_train_evaluation['cat_id'] == 'HOUSEHOLD'].set_index('cat_id')[d_cols]

# %%
try3.sum(axis=0).T.plot(figsize=(15, 5),title='HOUSEHOLD sales by week')
# Out:
# <Axes: title={'center': 'HOUSEHOLD sales by week'}>

# %%
try4 = sales_train_evaluation[(sales_train_evaluation['state_id'] == 'CA') & (sales_train_evaluation['cat_id'] == 'FOODS')]

# %%
total_sales_ca_foods = try4[d_cols].sum(axis=0).T

# %%
total_sales_ca_foods.plot(figsize=(15, 5))
# Out:
# <Axes: >

# %%
try5 = sales_train_evaluation[(sales_train_evaluation['state_id'] == 'CA') & (sales_train_evaluation['cat_id'] == 'HOUSEHOLD')]

# %%
try6 = sales_train_evaluation[(sales_train_evaluation['state_id'] == 'CA') & (sales_train_evaluation['cat_id'] == 'HOBBIES')]

# %%
total_sales_ca_households = try5[d_cols].sum(axis=0).T
total_sales_ca_households
# Out:
# d_1       2292
# d_2       2382
# d_3       1692
# d_4       1778
# d_5       1566
#           ...
# d_1937    3607
# d_1938    3912
# d_1939    4101
# d_1940    5913
# d_1941    6160
# Length: 1941, dtype: int64

# %%
total_sales_ca_hobbies = try6[d_cols].sum(axis=0).T
total_sales_ca_hobbies
# Out:
# d_1       1802
# d_2       1561
# d_3       1472
# d_4       1405
# d_5       1181
#           ...
# d_1937    1606
# d_1938    1735
# d_1939    1975
# d_1940    2701
# d_1941    2514
# Length: 1941, dtype: int64

# %%
plt.figure(figsize=(15,5))
plt.plot(d_cols, total_sales_ca_foods, label='FOODS')
plt.plot(d_cols, total_sales_ca_households, label='HOUSEHOLD', color='r')
plt.plot(d_cols, total_sales_ca_hobbies, label='HOBBIES', color='y')
plt.xlabel('Weeks')
plt.ylabel('Total Sales')
plt.title('Total Sales by Category in California Over Week')
# Out:
# Text(0.5, 1.0, 'Total Sales by Category in California Over Week')

# %%
try7 = sales_train_evaluation[(sales_train_evaluation['state_id'] == 'WI') & (sales_train_evaluation['cat_id'] == 'FOODS')]
try8 = sales_train_evaluation[(sales_train_evaluation['state_id'] == 'WI') & (sales_train_evaluation['cat_id'] == 'HOUSEHOLD')]
try9 = sales_train_evaluation[(sales_train_evaluation['state_id'] == 'WI') & (sales_train_evaluation['cat_id'] == 'HOBBIES')]

# %%
total_sales_wi_foods = try7[d_cols].sum(axis=0).T
total_sales_wi_hobbies = try8[d_cols].sum(axis=0).T
total_sales_wi_households = try9[d_cols].sum(axis=0).T

# %%
plt.figure(figsize=(15,5))
plt.plot(d_cols, total_sales_wi_foods, label='FOODS')
plt.plot(d_cols, total_sales_wi_households, label='HOUSEHOLD', color='r')
plt.plot(d_cols, total_sales_wi_hobbies, label='HOBBIES', color='y')
plt.xlabel('Weeks')
plt.ylabel('Total Sales')
plt.title('Total Sales by Category in Wisconsin Over Week')
# Out:
# Text(0.5, 1.0, 'Total Sales by Category in Wisconsin Over Week')

# %%
try10 = sales_train_evaluation[(sales_train_evaluation['state_id'] == 'TX') & (sales_train_evaluation['cat_id'] == 'FOODS')]
try11 = sales_train_evaluation[(sales_train_evaluation['state_id'] == 'TX') & (sales_train_evaluation['cat_id'] == 'HOUSEHOLD')]
try12 = sales_train_evaluation[(sales_train_evaluation['state_id'] == 'TX') & (sales_train_evaluation['cat_id'] == 'HOBBIES')]
total_sales_tx_foods = try10[d_cols].sum(axis=0).T
total_sales_tx_hobbies = try11[d_cols].sum(axis=0).T
total_sales_tx_households = try12[d_cols].sum(axis=0).T

# %%
plt.figure(figsize=(15,5))
plt.plot(d_cols, total_sales_tx_foods, label='FOODS')
plt.plot(d_cols, total_sales_tx_households, label='HOUSEHOLD', color='r')
plt.plot(d_cols, total_sales_tx_hobbies, label='HOBBIES', color='y')
plt.xlabel('Weeks')
plt.ylabel('Total Sales')
plt.title('Total Sales by Category in Texas Over Week')
# Out:
# Text(0.5, 1.0, 'Total Sales by Category in Texas Over Week')

# %%
By_date = sales_train_evaluation.set_index('id')[d_cols].T.merge(calendar.set_index('d')['date'],left_index=True,right_index=True,validate='1:1').set_index('date')
By_date
# Out:
#             HOBBIES_1_001_CA_1_evaluation  HOBBIES_1_002_CA_1_evaluation  \
# date
# 2011-01-29                              0                              0
# 2011-01-30                              0                              0
# 2011-01-31                              0                              0
# 2011-02-01                              0                              0
# 2011-02-02                              0                              0
# ...                                   ...                            ...
# 2016-05-18                              0                              0
# 2016-05-19                              3                              0
# 2016-05-20                              3                              0
# 2016-05-21                              0                              0
# 2016-05-22                              1                              0
#
#             HOBBIES_1_003_CA_1_evaluation  HOBBIES_1_004_CA_1_evaluation  \
# date
# ...

# %%
calendar
# Out:
#             date  wm_yr_wk    weekday  wday  month  year       d  \
# 0     2011-01-29     11101   Saturday     1      1  2011     d_1
# 1     2011-01-30     11101     Sunday     2      1  2011     d_2
# 2     2011-01-31     11101     Monday     3      1  2011     d_3
# 3     2011-02-01     11101    Tuesday     4      2  2011     d_4
# 4     2011-02-02     11101  Wednesday     5      2  2011     d_5
# ...          ...       ...        ...   ...    ...   ...     ...
# 1964  2016-06-15     11620  Wednesday     5      6  2016  d_1965
# 1965  2016-06-16     11620   Thursday     6      6  2016  d_1966
# 1966  2016-06-17     11620     Friday     7      6  2016  d_1967
# 1967  2016-06-18     11621   Saturday     1      6  2016  d_1968
# 1968  2016-06-19     11621     Sunday     2      6  2016  d_1969
#
#       event_name_1 event_type_1  event_name_2 event_type_2  snap_CA  snap_TX  \
# 0              NaN          NaN           NaN          NaN        0        0
# ...

# %%
calendar['event_name_1'].describe()
# Out:
# count           162
# unique           30
# top       SuperBowl
# freq              6
# Name: event_name_1, dtype: object

# %%
calendar['event_type_1'].describe()
# Out:
# count           162
# unique            4
# top       Religious
# freq             55
# Name: event_type_1, dtype: object

# %%
calendar['event_type_1'].unique()
# Out:
# array([nan, 'Sporting', 'Cultural', 'National', 'Religious'], dtype=object)

# %%
calendar['event_name_2'].describe()
# Out:
# count                5
# unique               4
# top       Father's day
# freq                 2
# Name: event_name_2, dtype: object

# %%
calendar['event_type_2'].describe()
# Out:
# count            5
# unique           2
# top       Cultural
# freq             4
# Name: event_type_2, dtype: object

# %%
calendar['event_type_2'].unique()
# Out:
# array([nan, 'Cultural', 'Religious'], dtype=object)

# %%
category_counts = calendar['event_type_1'].value_counts()
category_counts
# Out:
# event_type_1
# Religious    55
# National     52
# Cultural     37
# Sporting     18
# Name: count, dtype: int64

# %%
category_counts.plot(kind='bar', color='skyblue')
plt.xlabel('Categories')
plt.xticks(rotation=0)
plt.ylabel('Count')
plt.title('Count of Categories')
# Out:
# Text(0.5, 1.0, 'Count of Categories')

# %%
calendar['snap_WI'].value_counts().plot(kind='bar', color='skyblue')


plt.xlabel('Snap Day')
plt.xticks(rotation=0)
plt.ylabel('count')
plt.title('Count of Snap Days in WI')

# %%
calendar['snap_CA'].value_counts()
# Out:
# snap_CA
# 0    1319
# 1     650
# Name: count, dtype: int64

# %%
calendar['snap_WI'].value_counts()
# Out:
# snap_WI
# 0    1319
# 1     650
# Name: count, dtype: int64

# %%
calendar['snap_TX'].value_counts()
# Out:
# snap_TX
# 0    1319
# 1     650
# Name: count, dtype: int64

# %%
set1 = calendar['snap_CA'].value_counts().plot(kind='bar', color='skyblue')
set2 = calendar['snap_TX'].value_counts().plot(kind='bar', color='skyblue')
set3 = calendar['snap_WI'].value_counts().plot(kind='bar', color='skyblue')
x = 2
bar_width = 0.35
plt.bar(set1,2)
plt.bar(set2,2)
plt.xlabel('Snap Day')
plt.xticks(rotation=0)
plt.ylabel('count')
plt.title('Count of Snap Days in WI')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/opt/anaconda3/envs/FIT3163/lib/python3.9/site-packages/matplotlib/axes/_axes.py:2450, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2449 try:
# -> 2450     left = x - width / 2
#    2451 except TypeError as e:
#
# TypeError: unsupported operand type(s) for -: 'Axes' and 'float'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 6
#       4 x = 2
#       5 bar_width = 0.35
# ----> 6 plt.bar(set1,2)
#       7 plt.bar(set2,2)
#       8 plt.xlabel('Snap Day')
#
# File ~/opt/anaconda3/envs/FIT3163/lib/python3.9/site-packages/matplotlib/pyplot.py:2439, in bar(x, height, width, bottom, align, data, **kwargs)
#    2435 @_copy_docstring_and_deprecators(Axes.bar)
#    2436 def bar(
# ...

# %%
# %matplotlib inline

# %%
lg = (merge['item_id'] == 'HOBBIES_1_001')

# %%
lg = merge.loc[lg]

# %%
lg
# Out:
#          store_id        item_id  wm_yr_wk  sell_price        date    weekday  \
# 0            CA_1  HOBBIES_1_001     11325        1.21  2013-07-13   Saturday
# 1            CA_1  HOBBIES_1_001     11325        1.21  2013-07-14     Sunday
# 2            CA_1  HOBBIES_1_001     11325        1.21  2013-07-15     Monday
# 3            CA_1  HOBBIES_1_001     11325        1.21  2013-07-16    Tuesday
# 4            CA_1  HOBBIES_1_001     11325        1.21  2013-07-17  Wednesday
# ...           ...            ...       ...         ...         ...        ...
# 30878926     WI_1  HOBBIES_1_001     11621        1.18  2016-06-19     Sunday
# 30885023     WI_2  HOBBIES_1_001     11621        1.18  2016-06-18   Saturday
# 30885024     WI_2  HOBBIES_1_001     11621        1.18  2016-06-19     Sunday
# 30891121     WI_3  HOBBIES_1_001     11621        1.18  2016-06-18   Saturday
# 30891122     WI_3  HOBBIES_1_001     11621        1.18  2016-06-19     Sunday
#
# ...

# %%
lg_hb = lg['item_id'],lg['year']

# %%
lg_hb = lg.loc[:,['item_id','sell_price','year']]

# %%
lg_hb
# Out:
#                 item_id  sell_price  year
# 0         HOBBIES_1_001        1.21  2013
# 1         HOBBIES_1_001        1.21  2013
# 2         HOBBIES_1_001        1.21  2013
# 3         HOBBIES_1_001        1.21  2013
# 4         HOBBIES_1_001        1.21  2013
# ...                 ...         ...   ...
# 30878926  HOBBIES_1_001        1.18  2016
# 30885023  HOBBIES_1_001        1.18  2016
# 30885024  HOBBIES_1_001        1.18  2016
# 30891121  HOBBIES_1_001        1.18  2016
# 30891122  HOBBIES_1_001        1.18  2016
#
# [10646 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 from scipy.stats import linregress
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# !pip install scipy

# %%
pip install scipy
# Out:
# ...
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/03/c3/5162f7d23a12c62cf0630f6cce20932f166fca7cb5513ed9af56b5618ba6/scipy-1.11.2-cp39-cp39-macosx_10_9_x86_64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.1/54.1 kB 888.4 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.2/37.2 MB 12.4 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
x = lg_hb['sell_price']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = lg_hb['sell_price']
#
# NameError: name 'lg_hb' is not defined
